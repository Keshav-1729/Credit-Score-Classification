# %%
from imblearn.combine import SMOTEENN
from imblearn.combine import SMOTETomek
import pandas as pd
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('Model_data.csv')
df
# Out:
#         Month  Age     Occupation  Annual_Income  Monthly_Inhand_Salary  \
# 0        July   39         Writer      46477.560            4059.130000
# 1        July   52       Mechanic     153147.640           12915.303333
# 2       March   39         Doctor      16833.105            1542.758750
# 3         May   31  Media_Manager     131693.370           10696.447500
# 4      August   33   Entrepreneur      22233.980            1933.831667
# ...       ...  ...            ...            ...                    ...
# 63672  August   35       Mechanic    7749555.000            5774.633333
# 63673   April   18  Not Specified     132753.520           10853.793333
# 63674   April   32         Lawyer      26265.810            2464.817500
# 63675   April   39     Accountant      31407.100            2615.258333
# 63676  August   55       Musician      21700.680            1808.390000
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  Num_of_Loan  \
# ...

# %%
l=[]
for i in df.columns:
    if df[i].dtype=='object':
        l.append(i)
l
# Out:
# ['Month', 'Occupation', 'Payment_of_Min_Amount', 'Payment_Behaviour', 'Output']

# %%
new_df=df[['Annual_Income', 'Total_EMI_per_month', 'Interest_Rate',
       'Num_Credit_Inquiries', 'Payment_of_Min_Amount', 'Num_Credit_Card',
       'Num_Bank_Accounts', 'Credit_History_Age', 'Num_of_Delayed_Payment',
       'Num_of_Loan', 'Credit_Mix', 'Age','Output']]

# %%
new_df
# Out:
#        Annual_Income  Total_EMI_per_month  Interest_Rate  \
# 0          46477.560           212.248190             24
# 1         153147.640            81.918963              3
# 2          16833.105            51.702938              4
# 3         131693.370           208.858473             10
# 4          22233.980            39.598024              3
# ...              ...                  ...            ...
# 63672    7749555.000            51.878854              9
# 63673     132753.520           268.916569              6
# 63674      26265.810            46.662502             17
# 63675      31407.100           115.206873             29
# 63676      21700.680           212.314493             10
#
#        Num_Credit_Inquiries Payment_of_Min_Amount  Num_Credit_Card  \
# 0                      12.0                    NM               10
# 1                       1.0                    No                4
# 2                       6.0                    No                5
# ...

# %%
def to_cat1(i):
    if i =='Yes':
        return 2
    elif i=='NM':
        return 1
    else:
        return 0
new_df['Payment_of_Min_Amount']=new_df['Payment_of_Min_Amount'].apply(to_cat1)
# Out:
# C:\Users\Keshav\AppData\Local\Temp\ipykernel_22080\3180291743.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Payment_of_Min_Amount']=new_df['Payment_of_Min_Amount'].apply(to_cat1)

# %%
def to_cat2(i):
    if i =='Good':
        return 2
    elif i=='Standard':
        return 1
    else:
        return 0
new_df['Output']=new_df['Output'].apply(to_cat2)
# Out:
# C:\Users\Keshav\AppData\Local\Temp\ipykernel_22080\1545663338.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   new_df['Output']=new_df['Output'].apply(to_cat2)

# %%
new_df
# Out:
#        Annual_Income  Total_EMI_per_month  Interest_Rate  \
# 0          46477.560           212.248190             24
# 1         153147.640            81.918963              3
# 2          16833.105            51.702938              4
# 3         131693.370           208.858473             10
# 4          22233.980            39.598024              3
# ...              ...                  ...            ...
# 63672    7749555.000            51.878854              9
# 63673     132753.520           268.916569              6
# 63674      26265.810            46.662502             17
# 63675      31407.100           115.206873             29
# 63676      21700.680           212.314493             10
#
#        Num_Credit_Inquiries  Payment_of_Min_Amount  Num_Credit_Card  \
# 0                      12.0                      1               10
# 1                       1.0                      0                4
# 2                       6.0                      0                5
# ...

# %%
new_df.to
